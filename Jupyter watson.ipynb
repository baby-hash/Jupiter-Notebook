# %% [markdown]
# # My Jupyter Notebook on IBM Watson.ai

# %% [markdown]
# ### Author
# ##### Violet Chacha- Data Analyst

# %% [markdown]
# I am interested in data science because data can tell a story, and I want to be the one to tell it. I think analysing data from messy to organized is an interesting journey that I get the opportunity to take with every project I undertake.

# %% [markdown]
# ### Below is and arithmetic expression displaying multiplication of values.

# %%
(3*2)*10
# Out:
# 60

# %% [markdown]
# ##### Other expressions include:
# 1. Addition
# 2. Subtraction
# 3. Division
#
# #### Lists can be used to describe:
# - Temperature of places
# - Humidity of places
# - Shopping lists
#
# #### Example of a shopping list includes:
# | Grocery list |
# | ------------ |
# |Apples |
# | Pineapples |
# | Tomatos |
# | Green vegetables |
